# %%
import pandas as pd
import numpy as np

# Q1.a
df = pd.read_csv("./iris.csv")
df.head(7)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa

# %%
# Q1.b
df.tail(3)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
# Q1.c
df = df.rename({"sepal.length":"sepal_length",
                "sepal.width":"sepal_width",
                "petal.length":"petal_length",
                "petal.width":"petal_width",
                "variety":"species"},
               axis=1)
df.tail(7)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 143           6.8          3.2           5.9          2.3  Virginica
# 144           6.7          3.3           5.7          2.5  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
# Q1.d
df.loc[50:70,:]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  Versicolor
# 51           6.4          3.2           4.5          1.5  Versicolor
# 52           6.9          3.1           4.9          1.5  Versicolor
# 53           5.5          2.3           4.0          1.3  Versicolor
# 54           6.5          2.8           4.6          1.5  Versicolor
# 55           5.7          2.8           4.5          1.3  Versicolor
# 56           6.3          3.3           4.7          1.6  Versicolor
# 57           4.9          2.4           3.3          1.0  Versicolor
# 58           6.6          2.9           4.6          1.3  Versicolor
# 59           5.2          2.7           3.9          1.4  Versicolor
# 60           5.0          2.0           3.5          1.0  Versicolor
# 61           5.9          3.0           4.2          1.5  Versicolor
# 62           6.0          2.2           4.0          1.0  Versicolor
# ...

# %%
# Q1.e
sum(df["species"] == "Versicolor")
# Out:
# 50

# %%
# Q1f
sum(df["species"] == "Virginica")
# Out:
# 50

# %%
# Q1.g
sum(df["species"] == "Setosa")
# Out:
# 50

# %%
# Q1.h
new_data = {"sepal_length":[4.9,6.4,5.9,4.8],
            "sepal_width":[3.5,2.9,2.3,3.4],
            "petal_length":[1.4,4.5,4.2,1.4],
            "petal_width":[0.3,1.4,1.1,0.2],
            "species":["Setosa","Versicolor","Versicolor","Setosa"]}
new_df = pd.DataFrame(new_data)
new_df
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           4.9          3.5           1.4          0.3      Setosa
# 1           6.4          2.9           4.5          1.4  Versicolor
# 2           5.9          2.3           4.2          1.1  Versicolor
# 3           4.8          3.4           1.4          0.2      Setosa

# %%
# Q1.i
df = df.append(new_df).reset_index().drop(["index"],axis=1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      Setosa
# 1             4.9          3.0           1.4          0.2      Setosa
# 2             4.7          3.2           1.3          0.2      Setosa
# 3             4.6          3.1           1.5          0.2      Setosa
# 4             5.0          3.6           1.4          0.2      Setosa
# ..            ...          ...           ...          ...         ...
# 149           5.9          3.0           5.1          1.8   Virginica
# 150           4.9          3.5           1.4          0.3      Setosa
# 151           6.4          2.9           4.5          1.4  Versicolor
# 152           5.9          2.3           4.2          1.1  Versicolor
# 153           4.8          3.4           1.4          0.2      Setosa
#
# [154 rows x 5 columns]

# %%
# Q1.j
print(df.shape[0])
# Out:
# 154

# %%
# Q1.k
df.tail(7)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 147           6.5          3.0           5.2          2.0   Virginica
# 148           6.2          3.4           5.4          2.3   Virginica
# 149           5.9          3.0           5.1          1.8   Virginica
# 150           4.9          3.5           1.4          0.3      Setosa
# 151           6.4          2.9           4.5          1.4  Versicolor
# 152           5.9          2.3           4.2          1.1  Versicolor
# 153           4.8          3.4           1.4          0.2      Setosa

# %%
# Q1.l
import matplotlib.pyplot as plt
x=df["sepal_length"]
y=df["sepal_width"]
plt.scatter(x,y)
plt.title("iris_Flower_Dataset")
plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
# Q1.m
# method 1
x1 = df[df["species"] == "Setosa"]["sepal_length"]
y1 = df[df["species"] == "Setosa"]["sepal_width"]
x2 = df[df["species"] == "Versicolor"]["sepal_length"]
y2 = df[df["species"] == "Versicolor"]["sepal_width"]
x3 = df[df["species"] == "Virginica"]["sepal_length"]
y3 = df[df["species"] == "Virginica"]["sepal_width"]
plt.scatter(x1,y1,c="red")
plt.scatter(x2,y2,c="green")
plt.scatter(x3,y3,c="blue")
plt.title("iris_Flower_Dataset")
plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
plt.legend({"Setosa":"red","Versicolor":"green","Virginica":"blue"})
